# %% [markdown]
# **O que vamos fazer:**
#
# 1 - Filtrar a base
#
# 2 - Calcular entropias e divergencias
#
# 3 - Classificar
#
# -----------------------------------------------------------
# **Classificação do discurso:**
#
# 2 - regular
#
# 1 - ofenssivo
#
# 0 - hate speech

# %% [markdown]
# **Bibliotecas:**

# %%
from sklearn.feature_extraction.text import CountVectorizer
from scipy.stats import entropy
from math import log, e
from wordcloud import WordCloud

import pandas as pd
import nltk
import re
import numpy as np

nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/luisabraga/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/luisabraga/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/luisabraga/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/luisabraga/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/luisabraga/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/luisabraga/nltk_data...
# ...

# %% [markdown]
# ## Importação do dataset

# %%
labeled_data = pd.read_csv('labeled_data.csv')
labeled_data.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %% [markdown]
# ## Segregação dos dados

# %%
is_hate = labeled_data['class'] == 0
is_offensive = labeled_data['class'] == 1
is_regular = labeled_data['class'] == 2

hate_data = labeled_data[is_hate]
offensive_data = labeled_data[is_offensive]
regular_data = labeled_data[is_regular]

# %% [markdown]
# ## Informações sobre a base

# %%
print('A base de dados apresenta {} registros e {} variáveis'.format(labeled_data.shape[0], labeled_data.shape[1]))
print('Quantidade de tweets com ódio: {}'.format(hate_data.shape[0]))
print('Quantidade de tweets ofensivos: {}'.format(offensive_data.shape[0]))
print('Quantidade de tweets regulares: {}'.format(regular_data.shape[0]))
# Out:
# A base de dados apresenta 24783 registros e 7 variáveis
# Quantidade de tweets com ódio: 1430
# Quantidade de tweets ofensivos: 19190
# Quantidade de tweets regulares: 4163

# %% [markdown]
# ## Tratamento de tweets

# %%
def treat_string():
    stop_words = stopwords.words('english')
    lower_chars = lambda tweet: tweet.lower()
    remove_rt_user = lambda word: re.sub(r'(!* RT @[A-Za-z0-9_]*)|(!*"@[A-Za-z0-9_]*)', '', word)
    remove_user = lambda word: re.sub(r'@[A-Za-z0-9_]*', '', word)
    remove_rt = lambda word: re.sub(r' rt ', '', word)
    remove_special_char = lambda word: re.sub(r'[!.,\-";:~><^%$#@&*\(\)-+=_\'\?]','', word)
    remove_stopwords = lambda tweet: ' '.join([word for word in tweet.split(' ') if word not in stop_words])

    labeled_data['tweet_1'] = labeled_data['tweet'].apply(remove_rt_user)  # remove o inicio '!!!! RT @sjdha'
    labeled_data['tweet_1'] = labeled_data['tweet_1'].apply(lower_chars)   # coloca tudo em minusculo
    labeled_data['tweet_1'] = labeled_data['tweet_1'].apply(remove_user)   # remove os usuarios
    labeled_data['tweet_1'] = labeled_data['tweet_1'].apply(remove_rt)   # remove os rt
    labeled_data['tweet_1'] = labeled_data['tweet_1'].apply(remove_special_char)   # remove os caracteres especiais
    labeled_data['tweet_2'] = labeled_data['tweet_1'].apply(remove_stopwords)      # remove as stopwords

# %%
labeled_data['tweet'][2931]
# Out:
# '@DON_Le3GGG lol hell ya dey think a nicca down der #roadrunnin'

# %% [markdown]
# ## Geração da matriz de probabilidades

# %%
tf_data = CountVectorizer()
tf_hate = CountVectorizer()
tf_offensive = CountVectorizer()
tf_regular = CountVectorizer()

bow_data = tf_data.fit_transform(labeled_data['tweet'])
bow_hate = tf_hate.fit_transform(hate_data['tweet'])
bow_offensive = tf_offensive.fit_transform(offensive_data['tweet'])
bow_regular = tf_regular.fit_transform(regular_data['tweet'])

# %% [markdown]
# **Vocabulários:**

# %%
voc_data = tf_data.vocabulary_
voc_hate = tf_hate.vocabulary_
voc_offensive = tf_offensive.vocabulary_
voc_regular = tf_regular.vocabulary_

voc_data_size = len(voc_data.keys())
voc_hate_size = len(voc_hate.keys())
voc_offensive_size = len(voc_offensive.keys())
voc_regular_size = len(voc_regular.keys())

# %% [markdown]
# **Matrizes de TFs:**

# %%
matrix_data = bow_data.toarray()
matrix_hate = bow_hate.toarray()
matrix_offensive = bow_offensive.toarray()
matrix_regular = bow_regular.toarray()

# %% [markdown]
# ## Calculo dos histogramas

# %% [markdown]
# O **histograma individual** é calculado para cada documento da base de dados, isto é, considera somente os valores de TF das palavras que compõe o documento individualmente.

# %% [markdown]
# O **histograma de referência** considera os valores de TF das palavas do vocabulário por tipo discurso, isto é, para cada rótulo do problema de classificação de texto, será computado um histograma de referência.

# %%
def reference_histogram(matrix):
    result = []

# %% [markdown]
# ## Calculo de Entropias

# %% [markdown]
# Entropia de **Shanon**:

# %%
i_shanon_hate = dict({}) # dicionario para guardar entropias com o histograma individual de ódio
doc_hate_id = 0

for line in bow_hate.toarray():
    i_shanon_hate[doc_hate_id] = entropy(line)/log(voc_hate_size)
    doc_hate_id +=1
    
i_shanon_offensive = dict({}) # dicionario para guardar entropias com o histograma individual ofensivo
doc_offensive_id = 0

for line in bow_offensive.toarray():
    i_shanon_offensive[doc_offensive_id] = entropy(line)/log(voc_offensive_size)
    doc_offensive_id +=1

i_shanon_regular = dict({}) # dicionario para guardar entropias com o histograma individual regular
doc_regular_id = 0

for line in bow_regular.toarray():
    i_shanon_regular[doc_regular_id] = entropy(line)/log(voc_regular_size)
    doc_regular_id +=1

# %% [markdown]
# ## WordClouds

# %%
# pega todas as palavras de cada classe
hate_words = tf_hate.get_feature_names()
offensive_words = tf_offensive.get_feature_names()
regular_words = tf_regular.get_feature_names

all_hate_words = ' '.join([texto for texto in hate_data['tweet']]).replace('RT', '').lower()
all_offensive_words = ' '.join([texto for texto in offensive_data['tweet']]).replace('RT', '').lower()
all_regular_words = ' '.join([texto for texto in regular_data['tweet']]).replace('RT', '').lower()

# %%
# %matplotlib inline

hate_cloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False, 
                          max_words=100,
                          background_color="white").generate(all_hate_words)

offensive_cloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False,
                          max_words=100,
                          background_color="white").generate(all_offensive_words)

regular_cloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False,
                          max_words=100,
                          background_color="white").generate(all_regular_words)

# %%
plt.figure(figsize=(10,7))
plt.imshow(hate_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.imshow(offensive_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.imshow(regular_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
